# %%
# Importing librabries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import requests
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Desktop\Important\pythondata\Sim\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.olx.in/'
driver.get(url)

# %%
sc=driver.find_element(By.XPATH,'//*[@id="container"]/div[1]/div/div/div[1]/div[2]/div[1]/a')
sc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ce2a7f9632cf05bbedef930e3d40dc4d", element="8316a7e8-1ebf-4614-bd40-bbe1ce96e0ca")>

# %%
sc.click()

# %%
sa=driver.find_element(By.XPATH,'//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[42]/div/button')
sa.click()

# %%
sa1=driver.find_elements(By.XPATH,'//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[82]/div/button')
sa1[0].click()

# %%
sa2=driver.find_elements(By.XPATH,'//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[122]/div/button')
sa2[0].click()

# %%
sa3=driver.find_elements(By.XPATH,'//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[122]/div/button')
sa3[0].click()

# %%
sa4=driver.find_elements(By.XPATH,'//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li[62]/div/button')
sa4[0].click()

# %%
n=driver.find_elements(By.XPATH,'//div[@class ="_4aNdc"]')

# %%
n[0].text.split(',')[0]
# Out:
# 'Volkswagen Tiguan'

# %%
cn=[]
for i in range (0, len(n)):
    cn.append(n[i].text.split(',')[0])

# %%
len(cn)
# Out:
# 222

# %%
cn
# Out:
# ['Volkswagen Tiguan',
#  'Mercedes-Benz New C-Class',
#  'Skoda Yeti',
#  'Maruti Suzuki Ciaz',
#  'Hyundai Creta',
#  'Audi Q3',
#  'BMW X5',
#  'Hyundai Santro Xing',
#  'Skoda Rapid',
#  'Skoda Rapid',
#  'Maruti Suzuki SX4',
#  'Hyundai Sonata Transform',
#  'BMW 3 Series',
#  'Hyundai i10',
#  'Mahindra XUV500',
#  'Tata Safari Storme',
#  'Mahindra Thar',
#  'Mahindra Scorpio',
#  'Volkswagen Beetle',
#  'Volkswagen Vento',
#  'Honda City',
#  'Maruti Suzuki Alto 800',
#  'Hyundai i20',
#  'Maruti Suzuki Alto',
#  'BMW X1',
#  'Maruti Suzuki Ciaz',
#  'Honda City',
#  'Maruti Suzuki Alto',
#  'Maruti Suzuki Alto',
#  'Maruti Suzuki Ertiga',
#  'Maruti Suzuki Celerio',
#  'Renault Duster',
#  'Hyundai i10',
#  'Hyundai Creta',
#  'Maruti Suzuki Ertiga',
#  'Mahindra Bolero',
#  'Toyota Etios',
#  'Hyundai Verna',
#  'Toyota Corolla Altis',
#  'Maruti Suzuki Eeco',
#  'BMW X1',
#  'Maruti Suzuki Ritz',
#  'Toyota Innova Crysta',
#  'Honda City',
#  'Honda Amaze',
# ...

# %%
y=driver.find_elements(By.XPATH,'//span[@class ="_3GOwr"]')

# %%
y[0].text.split(' ')[-1]
# Out:
# '24,75,000'

# %%
len(y)
# Out:
# 222

# %%
ra=[]
for i in range (0, len(y)):
    ra.append(y[i].text.split(' ')[-1])

# %%
ra
# Out:
# ['24,75,000',
#  '27,50,000',
#  '5,99,999',
#  '7,10,000',
#  '10,50,000',
#  '24,50,000',
#  '98,00,000',
#  '90,000',
#  '6,00,000',
#  '3,65,000',
#  '2,50,000',
#  '6,50,000',
#  '20,00,000',
#  '3,00,000',
#  '7,90,000',
#  '5,75,000',
#  '7,45,000',
#  '7,50,000',
#  '15,00,000',
#  '3,20,000',
#  '10,35,000',
#  '3,95,000',
#  '4,15,000',
#  '1,69,999',
#  '12,90,000',
#  '8,50,000',
#  '5,65,000',
#  '81,000',
#  '1,69,999',
#  '8,50,000',
#  '4,95,000',
#  '5,10,000',
#  '4,60,000',
#  '11,25,000',
#  '7,75,000',
#  '6,00,000',
#  '5,15,000',
#  '3,45,000',
#  '4,25,000',
#  '4,49,000',
#  '10,75,000',
#  '2,10,000',
#  '14,55,000',
#  '5,90,000',
#  '4,50,000',
#  '3,10,000',
#  '8,60,000',
#  '9,75,000',
#  '5,11,041',
#  '7,08,958',
#  '9,50,000',
#  '8,10,000',
#  '1,95,000',
#  '6,00,000',
#  '4,99,000',
#  '5,85,000',
#  '6,50,000',
#  '5,50,000',
#  '5,55,000',
#  '3,99,000',
#  '2,65,000',
#  '3,85,000',
#  '5,99,000',
#  '3,25,000',
#  '3,25,000',
#  '6,99,000',
# ...

# %%
yo=driver.find_elements(By.XPATH,'//div[@class ="KFHpP"]')

# %%
len(yo)
# Out:
# 222

# %%
yo[7].text.split(' ')
# Out:
# ['2007', '-', '75,000', 'km']

# %%
ye=[]
for i in range (0, len(n)):
    ye.append(yo[i].text.split(' ')[0])

# %%
ye
# Out:
# ['2017',
#  '2015',
#  '2012',
#  '2017',
#  '2018',
#  '2017',
#  '2020',
#  '2007',
#  '2015',
#  '2013',
#  '2011',
#  '2012',
#  '2015',
#  '2014',
#  '2012',
#  '2015',
#  '2017',
#  '2015',
#  '2010',
#  '2011',
#  '2021',
#  '2019',
#  '2013',
#  '2011',
#  '2012',
#  '2018',
#  '2014',
#  '2005',
#  '2011',
#  '2015',
#  '2016',
#  '2014',
#  '2017',
#  '2018',
#  '2015',
#  '2012',
#  '2014',
#  '2010',
#  '2011',
#  '2018',
#  '2012',
#  '2010',
#  '2016',
#  '2015',
#  '2015',
#  '2011',
#  '2012',
#  '2021',
#  '2017',
#  '2022',
#  '2019',
#  '2020',
#  '2012',
#  '2017',
#  '2016',
#  '2019',
#  '2018',
#  '2014',
#  '2014',
#  '2013',
#  '2012',
#  '2013',
#  '2014',
#  '2011',
#  '2012',
#  '2016',
#  '2015',
#  '2021',
#  '2021',
#  '2018',
#  '2017',
#  '2021',
#  '2014',
#  '2018',
#  '2013',
#  '2014',
#  '2016',
#  '2018',
#  '2009',
#  '2018',
#  '2012',
#  '2018',
#  '2008',
#  '2014',
#  '2006',
#  '2011',
#  '2011',
#  '2015',
#  '1981',
#  '2013',
# ...

# %%
p=driver.find_elements(By.XPATH,'//div[@class ="_1zvfB"]')

# %%
p[0].text.split('\n')[0]
# Out:
# 'Amanora'

# %%
pl=[]
for i in range (0, len(n)):
    pl.append(p[i].text.split('\n')[0])

# %%
len(pl)
# Out:
# 222

# %%
km=[]
for i in range (0, len(yo)):
    km.append(yo[i].text)

# %%
km
# Out:
# ['2017 - 70000.0 km',
#  '2015 - 57,900 km',
#  '2012 - 103000.0 km',
#  '2017 - 98,000 km',
#  '2018 - 22,900 km',
#  '2017 - 60,000 km',
#  '2020 - 20000.0 km',
#  '2007 - 75,000 km',
#  '2015 - 69,000 km',
#  '2013 - 70,000 km',
#  '2011 - 999,999 km',
#  '2012 - 70,000 km',
#  '2015 - 54,000 km',
#  '2014 - 77,000 km',
#  '2012 - 53,000 km',
#  '2015 - 74,750 km',
#  '2017 - 18,000 km',
#  '2015 - 65,000 km',
#  '2010 - 22,000 km',
#  '2011 - 71,000 km',
#  '2021 - 5,000 km',
#  '2019 - 76,715 km',
#  '2013 - 63,000 km',
#  '2011 - 64,000 km',
#  '2012 - 70,000 km',
#  '2018 - 90,621 km',
#  '2014 - 80,000 km',
#  '2005 - 50,000 km',
#  '2011 - 64,000 km',
#  '2015 - 106,000 km',
#  '2016 - 43,665 km',
#  '2014 - 98,235 km',
#  '2017 - 26,677 km',
#  '2018 - 68,000 km',
#  '2015 - 57,955 km',
#  '2012 - 150,000 km',
#  '2014 - 72,000 km',
#  '2010 - 60,000 km',
#  '2011 - 95,000 km',
#  '2018 - 78,000 km',
#  '2012 - 81,000 km',
#  '2010 - 98,000 km',
#  '2016 - 90382.0 km',
# ...

# %%
dr=[]
c=driver.find_elements(By.XPATH,'/html/body/div/div/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a')
for url in c:
    dr.append(url.get_attribute("href"))

# %%
dr
# Out:
# ['https://www.olx.in/item/volkswagen-tiguan-20-tdi-highline-2017-diesel-iid-1688093219',
#  'https://www.olx.in/item/mercedes-benz-new-c-class-c-220-cdi-avantgarde-2015-diesel-iid-1693533921',
#  'https://www.olx.in/item/skoda-yeti-2009-2013-ambition-4x2-2012-diesel-iid-1686650597',
#  'https://www.olx.in/item/maruti-suzuki-ciaz-2014-2017-vdi-plus-shvs-2017-diesel-iid-1696503199',
#  'https://www.olx.in/item/hyundai-creta-16-sx-option-2018-petrol-iid-1697957660',
#  'https://www.olx.in/item/audi-q3-35-tdi-premium-plus-sunroof-2017-diesel-iid-1696552395',
#  'https://www.olx.in/item/bmw-x5-xdrive-30d-xline-2020-diesel-iid-1685671728',
#  'https://www.olx.in/item/hyundai-santro-xing-xo-2007-petrol-iid-1691854591',
#  'https://www.olx.in/item/skoda-rapid-2013-2016-15-tdi-at-style-plus-black-package-2015-die-iid-1701552095',
#  'https://www.olx.in/item/skoda-rapid-2013-petrol-iid-1698824275',
#  'https://www.olx.in/item/maruti-suzuki-sx4-2011-diesel-iid-1702602487',
# ...

# %%
len(dr)
# Out:
# 222

# %%
ty=[]
for url in dr: ##loop for every guitar in the list
    driver.get(url)
    time.sleep(2)
    try:
        ty.append(driver.find_element(By.XPATH,'//div[@class ="_3qDp0"]').text)
    except:
        ty.append('-')

# %%
len(ty)
# Out:
# 222

# %%
ty
# Out:
# ['-',
#  'DIESEL',
#  '-',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  '-',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'CNG & HYBRIDS',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  '-',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'CNG & HYBRIDS',
#  'DIESEL',
#  'DIESEL',
#  '-',
#  'CNG',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL/COMPRESSED NATURAL GAS',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  '-',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  '-',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'LPG',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
# ...

# %%
len(ty)
# Out:
# 222

# %%
fy=[]
for i in range(len(ty)):
    if (ty[i]=='-'):
        fy.append('NAN')
    else:
        fy.append(ty[i])

# %%
fy
# Out:
# ['NAN',
#  'DIESEL',
#  'NAN',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'NAN',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'CNG & HYBRIDS',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'NAN',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'DIESEL',
#  'PETROL',
#  'CNG & HYBRIDS',
#  'DIESEL',
#  'DIESEL',
#  'NAN',
#  'CNG',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL/COMPRESSED NATURAL GAS',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'NAN',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'NAN',
#  'PETROL',
#  'DIESEL',
#  'PETROL',
#  'DIESEL',
#  'DIESEL',
#  'LPG',
#  'DIESEL',
#  'DIESEL',
# ...

# %%
ow=[]
for url in dr: ##loop for every guitar in the list
    driver.get(url)
    time.sleep(2)
    try:
        ow.append(driver.find_element(By.XPATH,'//div[@class ="_1gasz"]').text)
    except:
        ow.append('NAN')

# %%
len(ow)
# Out:
# 222

# %%
ow
# Out:
# ['NAN',
#  '1st',
#  'NAN',
#  '1st',
#  '1st',
#  '1st',
#  'NAN',
#  '3rd',
#  '1st',
#  'First',
#  'Third',
#  '1st',
#  '1st',
#  '--',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '--',
#  '1st',
#  '1st',
#  '2nd',
#  'Third',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '--',
#  'NAN',
#  'Second',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  'First',
#  '--',
#  'First',
#  'First',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  'First',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '3rd',
#  '1st',
#  '1st',
#  'First',
#  '1st',
#  'First',
#  'First',
#  '1st',
#  '1st',
#  '2nd',
#  'Fourth',
#  'First',
#  'NAN',
#  '1st',
#  '1st',
#  'First',
#  'First',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
# ...

# %%
# Buliding Dataset using scrapped information
q= pd.DataFrame(list(zip(cn,ye,ra,km,pl,fy,ow)),
               columns =['car name', 'year','price','distance','place','fuel','owner'])

# %%
q
# Out:
#                         car name  year      price            distance  \
# 0              Volkswagen Tiguan  2017  24,75,000   2017 - 70000.0 km
# 1      Mercedes-Benz New C-Class  2015  27,50,000    2015 - 57,900 km
# 2                     Skoda Yeti  2012   5,99,999  2012 - 103000.0 km
# 3             Maruti Suzuki Ciaz  2017   7,10,000    2017 - 98,000 km
# 4                  Hyundai Creta  2018  10,50,000    2018 - 22,900 km
# ..                           ...   ...        ...                 ...
# 217              Hyundai Elantra  2014   6,25,000    2014 - 85,000 km
# 218                  Skoda Laura  2009   1,85,000   2009 - 120,000 km
# 219       Maruti Suzuki Alto 800  2018   3,40,000     2018 - 1,888 km
# 220      Mercedes-Benz GLE Class  2019  56,00,000    2019 - 71,000 km
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999   2018 - 63000.0 km
#
#                    place    fuel owner
# 0                Amanora     NAN   NAN
# 1         Tatabad Colony  DIESEL   1st
# ...

# %%
q.to_csv('Carprice34.csv',index= False)

# %%
q
# Out:
#                         car name  year      price            distance  \
# 0              Volkswagen Tiguan  2017  24,75,000   2017 - 70000.0 km
# 1      Mercedes-Benz New C-Class  2015  27,50,000    2015 - 57,900 km
# 2                     Skoda Yeti  2012   5,99,999  2012 - 103000.0 km
# 3             Maruti Suzuki Ciaz  2017   7,10,000    2017 - 98,000 km
# 4                  Hyundai Creta  2018  10,50,000    2018 - 22,900 km
# ..                           ...   ...        ...                 ...
# 217              Hyundai Elantra  2014   6,25,000    2014 - 85,000 km
# 218                  Skoda Laura  2009   1,85,000   2009 - 120,000 km
# 219       Maruti Suzuki Alto 800  2018   3,40,000     2018 - 1,888 km
# 220      Mercedes-Benz GLE Class  2019  56,00,000    2019 - 71,000 km
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999   2018 - 63000.0 km
#
#                    place    fuel owner
# 0                Amanora     NAN   NAN
# 1         Tatabad Colony  DIESEL   1st
# ...

# %%
q.isnull().sum()
# Out:
# car name    0
# year        0
# price       0
# distance    0
# place       0
# fuel        0
# owner       0
# dtype: int64

# %%
# Import libraries need for Modelling
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
import pickle

import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# CAR PRICE PREDICTION
# With the covid 19 impact in the market, we have seen lot of changes in the car market. Now some cars are in demand hence making them costly and some are not in demand hence cheaper. One of our clients works with small traders, who sell used cars. With the change in market due to covid 19 impact, our client is facing problems with their previous car price valuation machine learning models. So, they are looking for new machine learning models from new data. We have to make car price valuation model. This project contains two phase-
# You have to scrape at least 5000 used cars data. You can scrape more data as well, it’s up to you. more the data better the model
# In this section You need to scrape the data of used cars from websites (Olx, cardekho, Cars24 etc.) You need web scraping for this. You have to fetch data for different locations. The number of
# columns for data doesn’t have limit, it’s up to you and your creativity. Generally, these columns are Brand, model, variant, manufacturing year, driven kilometers, fuel, number of owners, location and at last target variable Price of the car. This data is to give you a hint about important variables in used car model. You can make changes to it, you can add or you can remove some columns, it completely depends on the website from which you are fetching the data.
# Try to include all types of cars in your data for example- SUV, Sedans, Coupe, minivan, Hatchback.
# Note – The data which you are collecting is important to us. Kindly don’t share it on any public platforms.
# Model Building Phase
# After collecting the data, you need to build a machine learning model. Before model building do all data pre-processing steps. Try different models with different hyper parameters and select the best model.
# Follow the complete life cycle of data science. Include all the steps like.
# 1. Data Cleaning
# 2. Exploratory Data Analysis
# 3. Data Pre-processing
# 4. Model Building
# 5. Model Evaluation
# 6. Selecting the best model

# %%
# Reading CSV file and converting into dataframe
dt=pd.read_csv('Carprice34.csv')

# %%
dt
# Out:
#                         car name  year      price            distance  \
# 0              Volkswagen Tiguan  2017  24,75,000   2017 - 70000.0 km
# 1      Mercedes-Benz New C-Class  2015  27,50,000    2015 - 57,900 km
# 2                     Skoda Yeti  2012   5,99,999  2012 - 103000.0 km
# 3             Maruti Suzuki Ciaz  2017   7,10,000    2017 - 98,000 km
# 4                  Hyundai Creta  2018  10,50,000    2018 - 22,900 km
# ..                           ...   ...        ...                 ...
# 217              Hyundai Elantra  2014   6,25,000    2014 - 85,000 km
# 218                  Skoda Laura  2009   1,85,000   2009 - 120,000 km
# 219       Maruti Suzuki Alto 800  2018   3,40,000     2018 - 1,888 km
# 220      Mercedes-Benz GLE Class  2019  56,00,000    2019 - 71,000 km
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999   2018 - 63000.0 km
#
#                    place    fuel owner
# 0                Amanora     NAN   NAN
# 1         Tatabad Colony  DIESEL   1st
# ...

# %%
#Display head of dataset
dt.head(15)
# Out:
#                      car name  year      price            distance  \
# 0           Volkswagen Tiguan  2017  24,75,000   2017 - 70000.0 km
# 1   Mercedes-Benz New C-Class  2015  27,50,000    2015 - 57,900 km
# 2                  Skoda Yeti  2012   5,99,999  2012 - 103000.0 km
# 3          Maruti Suzuki Ciaz  2017   7,10,000    2017 - 98,000 km
# 4               Hyundai Creta  2018  10,50,000    2018 - 22,900 km
# 5                     Audi Q3  2017  24,50,000    2017 - 60,000 km
# 6                      BMW X5  2020  98,00,000   2020 - 20000.0 km
# 7         Hyundai Santro Xing  2007     90,000    2007 - 75,000 km
# 8                 Skoda Rapid  2015   6,00,000    2015 - 69,000 km
# 9                 Skoda Rapid  2013   3,65,000    2013 - 70,000 km
# 10          Maruti Suzuki SX4  2011   2,50,000   2011 - 999,999 km
# 11   Hyundai Sonata Transform  2012   6,50,000    2012 - 70,000 km
# 12               BMW 3 Series  2015  20,00,000    2015 - 54,000 km
# ...

# %%
#Display tail of dataset
dt.tail(15)
# Out:
#                         car name  year      price           distance  \
# 207                    Ford Figo  2010   2,50,000   2010 - 80,000 km
# 208              Toyota Fortuner  2017  27,25,000  2017 - 163,000 km
# 209          Maruti Suzuki Swift  2012   3,84,999    2012 - 9,746 km
# 210                   Honda City  2014   6,30,000   2014 - 60,000 km
# 211          Maruti Suzuki Swift  2010   3,15,000  2010 - 144,000 km
# 212           Tata Safari Storme  2013   5,50,000  2013 - 129,750 km
# 213                 Nissan Sunny  2013   2,35,000  2013 - 105,000 km
# 214         Maruti Suzuki Ertiga  2015   5,65,000   2015 - 42,000 km
# 215                Ford Ecosport  2013   4,40,000   2013 - 98,000 km
# 216           Hyundai i20 Active  2015   4,55,000  2015 - 102,000 km
# 217              Hyundai Elantra  2014   6,25,000   2014 - 85,000 km
# 218                  Skoda Laura  2009   1,85,000  2009 - 120,000 km
# 219       Maruti Suzuki Alto 800  2018   3,40,000    2018 - 1,888 km
# ...

# %%
print('The shape of the dataset is', dt.shape)
# Out:
# The shape of the dataset is (222, 7)

# %%
# Dataframe columns
dt.columns
# Out:
# Index(['car name', 'year', 'price', 'distance', 'place', 'fuel', 'owner'], dtype='object')

# %%
# To find types of data present in the dataset
dt.nunique()
# Out:
# car name    105
# year         20
# price       146
# distance    199
# place       169
# fuel          8
# owner         9
# dtype: int64

# %%
# To find the data type of the dataset
for col in dt:
    print ('This column', col ,'has', dt[col].unique(),'unique elements')
    print ('*'*100)
# Out:
# This column car name has ['Volkswagen Tiguan' 'Mercedes-Benz New C-Class' 'Skoda Yeti'
#  'Maruti Suzuki Ciaz' 'Hyundai Creta' 'Audi Q3' 'BMW X5'
#  'Hyundai Santro Xing' 'Skoda Rapid' 'Maruti Suzuki SX4'
#  'Hyundai Sonata Transform' 'BMW 3 Series' 'Hyundai i10' 'Mahindra XUV500'
#  'Tata Safari Storme' 'Mahindra Thar' 'Mahindra Scorpio'
#  'Volkswagen Beetle' 'Volkswagen Vento' 'Honda City'
#  'Maruti Suzuki Alto 800' 'Hyundai i20' 'Maruti Suzuki Alto' 'BMW X1'
#  'Maruti Suzuki Ertiga' 'Maruti Suzuki Celerio' 'Renault Duster'
#  'Mahindra Bolero' 'Toyota Etios' 'Hyundai Verna' 'Toyota Corolla Altis'
#  'Maruti Suzuki Eeco' 'Maruti Suzuki Ritz' 'Toyota Innova Crysta'
#  'Honda Amaze' 'Toyota Innova' 'Hyundai Venue' 'Toyota Etios Liva'
#  'Hyundai Grand i10 Nios' 'Tata Tiago' 'Toyota Etios Cross' 'Ford Fiesta'
#  'Maruti Suzuki Swift Dzire' 'Maruti Suzuki Swift' 'Maruti Suzuki S-Cross'
#  'BMW 5 Series' 'Maruti Suzuki Vitara Brezza' 'Land Rover Range Rover'
# ...

# %%
# Seeing for the null values in the dataset
dt.isna().sum()
# Out:
# car name    0
# year        0
# price       0
# distance    0
# place       0
# fuel        0
# owner       0
# dtype: int64

# %%
sns.heatmap(dt.isnull(), yticklabels = False, cbar = False, cmap ='viridis')
# Out:
# <AxesSubplot:>

# %%
# Getting information on the dataset
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car name  222 non-null    object
#  1   year      222 non-null    int64
#  2   price     222 non-null    object
#  3   distance  222 non-null    object
#  4   place     222 non-null    object
#  5   fuel      222 non-null    object
#  6   owner     222 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 12.3+ KB

# %%
# To find the correlection in the dataset
dt.corr()
# Out:
#       year
# year   1.0

# %%
# Analysing the data 
dt.describe().T
# Out:
#       count         mean       std     min     25%     50%     75%     max
# year  222.0  2014.788288  4.464566  1981.0  2012.0  2015.0  2018.0  2022.0

# %% [raw]
# So we can observe that distance travelled and price is tretated as object and there are NAN, -- junk data in fuel and owner
# from unique of the data set we can see that data scrapped have to be extracted.

# %%
dt['distance'][8].split('- ')
# Out:
# ['2015 ', '69,000 km']

# %%
er=[]
for i in range (222):
    er.append(dt['distance'][i].split('- ')[1])

# %%
len(er)
# Out:
# 222

# %%
dt['distance1']=er

# %%
dt
# Out:
#                         car name  year      price            distance  \
# 0              Volkswagen Tiguan  2017  24,75,000   2017 - 70000.0 km
# 1      Mercedes-Benz New C-Class  2015  27,50,000    2015 - 57,900 km
# 2                     Skoda Yeti  2012   5,99,999  2012 - 103000.0 km
# 3             Maruti Suzuki Ciaz  2017   7,10,000    2017 - 98,000 km
# 4                  Hyundai Creta  2018  10,50,000    2018 - 22,900 km
# ..                           ...   ...        ...                 ...
# 217              Hyundai Elantra  2014   6,25,000    2014 - 85,000 km
# 218                  Skoda Laura  2009   1,85,000   2009 - 120,000 km
# 219       Maruti Suzuki Alto 800  2018   3,40,000     2018 - 1,888 km
# 220      Mercedes-Benz GLE Class  2019  56,00,000    2019 - 71,000 km
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999   2018 - 63000.0 km
#
#                    place    fuel owner    distance1
# 0                Amanora     NAN   NAN   70000.0 km
# ...

# %%
dt.drop(columns='distance', inplace=True)

# %%
dt['distance1'][0].split(' ')[0]
# Out:
# '70000.0'

# %%
re=[]
for i in range (222):
    re.append(dt['distance1'][i].split(' ')[0])

# %%
re
# Out:
# ['70000.0',
#  '57,900',
#  '103000.0',
#  '98,000',
#  '22,900',
#  '60,000',
#  '20000.0',
#  '75,000',
#  '69,000',
#  '70,000',
#  '999,999',
#  '70,000',
#  '54,000',
#  '77,000',
#  '53,000',
#  '74,750',
#  '18,000',
#  '65,000',
#  '22,000',
#  '71,000',
#  '5,000',
#  '76,715',
#  '63,000',
#  '64,000',
#  '70,000',
#  '90,621',
#  '80,000',
#  '50,000',
#  '64,000',
#  '106,000',
#  '43,665',
#  '98,235',
#  '26,677',
#  '68,000',
#  '57,955',
#  '150,000',
#  '72,000',
#  '60,000',
#  '95,000',
#  '78,000',
#  '81,000',
#  '98,000',
#  '90382.0',
#  '70,000',
#  '29,000',
#  '64,000',
#  '255,232',
#  '45,900',
#  '37,037',
#  '1',
#  '20,000',
#  '20,000',
#  '75,000',
#  '8,800',
#  '61,000',
#  '15,000',
#  '53,000',
#  '52,980',
#  '128,000',
#  '54,980',
#  '55,000',
#  '89,000',
#  '92,980',
#  '97,980',
#  '78,000',
#  '75,980',
#  '47,980',
#  '9,300',
#  '4,867',
#  '65,000',
#  '55,000',
#  '20,000',
#  '65,200',
#  '63,000',
#  '115,000',
#  '62,443',
# ...

# %%
dt['Distance']=re

# %%
dt
# Out:
#                         car name  year      price                place  \
# 0              Volkswagen Tiguan  2017  24,75,000              Amanora
# 1      Mercedes-Benz New C-Class  2015  27,50,000       Tatabad Colony
# 2                     Skoda Yeti  2012   5,99,999    Veterinary Colony
# 3             Maruti Suzuki Ciaz  2017   7,10,000           Sector 29B
# 4                  Hyundai Creta  2018  10,50,000               Gahaur
# ..                           ...   ...        ...                  ...
# 217              Hyundai Elantra  2014   6,25,000          Anand Vihar
# 218                  Skoda Laura  2009   1,85,000  Amrit Varsha Colony
# 219       Maruti Suzuki Alto 800  2018   3,40,000          Mayur Vihar
# 220      Mercedes-Benz GLE Class  2019  56,00,000               Anchal
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999          Preet Vihar
#
#        fuel owner    distance1  Distance
# 0       NAN   NAN   70000.0 km   70000.0
# ...

# %%
dt.drop(columns='distance1', inplace=True)

# %%
dt
# Out:
#                         car name  year      price                place  \
# 0              Volkswagen Tiguan  2017  24,75,000              Amanora
# 1      Mercedes-Benz New C-Class  2015  27,50,000       Tatabad Colony
# 2                     Skoda Yeti  2012   5,99,999    Veterinary Colony
# 3             Maruti Suzuki Ciaz  2017   7,10,000           Sector 29B
# 4                  Hyundai Creta  2018  10,50,000               Gahaur
# ..                           ...   ...        ...                  ...
# 217              Hyundai Elantra  2014   6,25,000          Anand Vihar
# 218                  Skoda Laura  2009   1,85,000  Amrit Varsha Colony
# 219       Maruti Suzuki Alto 800  2018   3,40,000          Mayur Vihar
# 220      Mercedes-Benz GLE Class  2019  56,00,000               Anchal
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999          Preet Vihar
#
#        fuel owner  Distance
# 0       NAN   NAN   70000.0
# 1    DIESEL   1st    57,900
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car name  222 non-null    object
#  1   year      222 non-null    int64
#  2   price     222 non-null    object
#  3   place     222 non-null    object
#  4   fuel      222 non-null    object
#  5   owner     222 non-null    object
#  6   Distance  222 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 12.3+ KB

# %%
dt['fuel'].value_counts()
# Out:
# DIESEL                           97
# PETROL                           87
# CNG & HYBRIDS                    15
# NAN                              13
# CNG                               4
# --                                4
# LPG                               1
# PETROL/COMPRESSED NATURAL GAS     1
# Name: fuel, dtype: int64

# %%
dt['fuel'].replace(to_replace='--', value='DIESEL', inplace=True)

# %%
dt['fuel'].value_counts()
# Out:
# DIESEL                           101
# PETROL                            87
# CNG & HYBRIDS                     15
# NAN                               13
# CNG                                4
# LPG                                1
# PETROL/COMPRESSED NATURAL GAS      1
# Name: fuel, dtype: int64

# %% [raw]
# ownerAs it is catagerical column it was replaced by mode()

# %%
dt['fuel'].replace(to_replace='NAN', value='DIESEL', inplace=True)

# %%
dt
# Out:
#                         car name  year      price                place  \
# 0              Volkswagen Tiguan  2017  24,75,000              Amanora
# 1      Mercedes-Benz New C-Class  2015  27,50,000       Tatabad Colony
# 2                     Skoda Yeti  2012   5,99,999    Veterinary Colony
# 3             Maruti Suzuki Ciaz  2017   7,10,000           Sector 29B
# 4                  Hyundai Creta  2018  10,50,000               Gahaur
# ..                           ...   ...        ...                  ...
# 217              Hyundai Elantra  2014   6,25,000          Anand Vihar
# 218                  Skoda Laura  2009   1,85,000  Amrit Varsha Colony
# 219       Maruti Suzuki Alto 800  2018   3,40,000          Mayur Vihar
# 220      Mercedes-Benz GLE Class  2019  56,00,000               Anchal
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999          Preet Vihar
#
#        fuel owner  Distance
# 0    DIESEL   NAN   70000.0
# 1    DIESEL   1st    57,900
# ...

# %%
dt['owner'].value_counts()
# Out:
# 1st       128
# 2nd        28
# NAN        26
# First      14
# --          9
# 3rd         7
# Second      6
# Fourth      2
# Third       2
# Name: owner, dtype: int64

# %% [raw]
# ownerAs it is catagerical column it was replaced by mode()

# %%
dt['owner'].replace(to_replace='--', value='1st', inplace=True)

# %%
dt['owner'].replace(to_replace='NAN', value='1st', inplace=True)

# %%
dt
# Out:
#                         car name  year      price                place  \
# 0              Volkswagen Tiguan  2017  24,75,000              Amanora
# 1      Mercedes-Benz New C-Class  2015  27,50,000       Tatabad Colony
# 2                     Skoda Yeti  2012   5,99,999    Veterinary Colony
# 3             Maruti Suzuki Ciaz  2017   7,10,000           Sector 29B
# 4                  Hyundai Creta  2018  10,50,000               Gahaur
# ..                           ...   ...        ...                  ...
# 217              Hyundai Elantra  2014   6,25,000          Anand Vihar
# 218                  Skoda Laura  2009   1,85,000  Amrit Varsha Colony
# 219       Maruti Suzuki Alto 800  2018   3,40,000          Mayur Vihar
# 220      Mercedes-Benz GLE Class  2019  56,00,000               Anchal
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999          Preet Vihar
#
#        fuel owner  Distance
# 0    DIESEL   1st   70000.0
# 1    DIESEL   1st    57,900
# ...

# %%
# To find the data type of the dataset
for col in dt:
    print ('This column', col ,'has', dt[col].unique(),'unique elements')
    print ('*'*100)
# Out:
# This column car name has ['Volkswagen Tiguan' 'Mercedes-Benz New C-Class' 'Skoda Yeti'
#  'Maruti Suzuki Ciaz' 'Hyundai Creta' 'Audi Q3' 'BMW X5'
#  'Hyundai Santro Xing' 'Skoda Rapid' 'Maruti Suzuki SX4'
#  'Hyundai Sonata Transform' 'BMW 3 Series' 'Hyundai i10' 'Mahindra XUV500'
#  'Tata Safari Storme' 'Mahindra Thar' 'Mahindra Scorpio'
#  'Volkswagen Beetle' 'Volkswagen Vento' 'Honda City'
#  'Maruti Suzuki Alto 800' 'Hyundai i20' 'Maruti Suzuki Alto' 'BMW X1'
#  'Maruti Suzuki Ertiga' 'Maruti Suzuki Celerio' 'Renault Duster'
#  'Mahindra Bolero' 'Toyota Etios' 'Hyundai Verna' 'Toyota Corolla Altis'
#  'Maruti Suzuki Eeco' 'Maruti Suzuki Ritz' 'Toyota Innova Crysta'
#  'Honda Amaze' 'Toyota Innova' 'Hyundai Venue' 'Toyota Etios Liva'
#  'Hyundai Grand i10 Nios' 'Tata Tiago' 'Toyota Etios Cross' 'Ford Fiesta'
#  'Maruti Suzuki Swift Dzire' 'Maruti Suzuki Swift' 'Maruti Suzuki S-Cross'
#  'BMW 5 Series' 'Maruti Suzuki Vitara Brezza' 'Land Rover Range Rover'
# ...

# %% [raw]
# We can see that place is least important. The car and its model automatically indicate that its automatic or manual and sedan or other group so that car names are important

# %%
sns.pairplot(dt)

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['fuel'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.subplots(figsize=(50,50))
chart =sns.countplot(dt['place'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
dt['place'].value_counts()
# Out:
# Baner                     7
# Kalyani Nagar             5
# Noida Extension           4
# Amrit Varsha Colony       4
# Chembur                   4
#                          ..
# Tatabad Colony            1
# Malad East                1
# Hadapsar                  1
# Wadgaon Sheri Ramawadi    1
# H Colony                  1
# Name: place, Length: 169, dtype: int64

# %%
(dt['place'].value_counts()).plot(kind='barh', figsize=(80,80),fontsize=35)
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['year'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
plt.subplots(figsize=(10,10))
chart =sns.countplot(dt['owner'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
dt.drop(columns='place', inplace=True)

# %%
dt
# Out:
#                         car name  year      price    fuel owner  Distance
# 0              Volkswagen Tiguan  2017  24,75,000  DIESEL   1st   70000.0
# 1      Mercedes-Benz New C-Class  2015  27,50,000  DIESEL   1st    57,900
# 2                     Skoda Yeti  2012   5,99,999  DIESEL   1st  103000.0
# 3             Maruti Suzuki Ciaz  2017   7,10,000  DIESEL   1st    98,000
# 4                  Hyundai Creta  2018  10,50,000  PETROL   1st    22,900
# ..                           ...   ...        ...     ...   ...       ...
# 217              Hyundai Elantra  2014   6,25,000  PETROL   1st    85,000
# 218                  Skoda Laura  2009   1,85,000  DIESEL   1st   120,000
# 219       Maruti Suzuki Alto 800  2018   3,40,000  PETROL   1st     1,888
# 220      Mercedes-Benz GLE Class  2019  56,00,000  DIESEL   1st    71,000
# 221  Maruti Suzuki Vitara Brezza  2018   7,39,999  DIESEL   1st   63000.0
#
# [222 rows x 6 columns]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car name  222 non-null    int32
#  1   year      222 non-null    int64
#  2   price     222 non-null    float64
#  3   fuel      222 non-null    int32
#  4   owner     222 non-null    int32
#  5   Distance  222 non-null    float64
# dtypes: float64(2), int32(3), int64(1)
# memory usage: 7.9 KB

# %%
dt.groupby('car name')['price'].mean()
# Out:
# car name
# 0      2337500.0
# 1      2000000.0
# 2      3550000.0
# 3      6600000.0
# 4      1947500.0
#          ...
# 100    1500000.0
# 101     850000.0
# 102     432500.0
# 103    2475000.0
# 104     427500.0
# Name: price, Length: 105, dtype: float64

# %%
dt.groupby('car name')['Distance','price'].mean()
# Out:
#           Distance      price
# car name
# 0          51000.0  2337500.0
# 1          54000.0  2000000.0
# 2          17000.0  3550000.0
# 3           9300.0  6600000.0
# 4          74250.0  1947500.0
# ...            ...        ...
# 100        22000.0  1500000.0
# 101        93653.0   850000.0
# 102        82500.0   432500.0
# 103        70000.0  2475000.0
# 104        77745.0   427500.0
#
# [105 rows x 2 columns]

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder

# %%
# Assigning to a variable
le=LabelEncoder()

# %%
# Coverting all the catagorical variables to numerical in trianing dataset
dt['fuel']=le.fit_transform(dt['fuel'])
dt['car name']=le.fit_transform(dt['car name'])
dt['owner']=le.fit_transform(dt['owner'])

# %%
dt
# Out:
#      car name  year      price  fuel  owner  Distance
# 0         103  2017  2475000.0     2      0   70000.0
# 1          72  2015  2750000.0     2      0   57900.0
# 2          83  2012   599999.0     2      0  103000.0
# 3          51  2017   710000.0     2      0   98000.0
# 4          18  2018  1050000.0     4      0   22900.0
# ..        ...   ...        ...   ...    ...       ...
# 217        19  2014   625000.0     4      0   85000.0
# 218        80  2009   185000.0     2      0  120000.0
# 219        47  2018   340000.0     4      0    1888.0
# 220        71  2019  5600000.0     2      0   71000.0
# 221        63  2018   739999.0     2      0   63000.0
#
# [222 rows x 6 columns]

# %%
re=dt['Distance']

# %%
dt['Distance'] = dt['Distance'].apply(lambda x: float(x.split()[0].replace(',', '')))

# %%
dt['price'] = dt['price'].apply(lambda x: float(x.split()[0].replace(',', '')))

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car name  222 non-null    int64
#  1   year      222 non-null    int64
#  2   price     222 non-null    float64
#  3   fuel      222 non-null    int64
#  4   owner     222 non-null    int64
#  5   Distance  222 non-null    float64
# dtypes: float64(2), int64(4)
# memory usage: 10.5 KB

# %%
# Assignment of X and y
X=dt.drop(['price'], axis=1)
y=dt.price

# %%
# Standardization of the data
scalar= StandardScaler()
X_scaled=scalar.fit_transform(X)

# %%
# Applying machine learning models
# Importing machine learning libraries
# The problem is related regression the regression models are used
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error,mean_absolute_error, r2_score

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    li=LinearRegression()
    li.fit(x_train, y_train)
    predtrain=li.predict(x_train)
    predtest=li.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-eb305f9ff0bf> in <module>
#       1 for i in range(1,800):
# ----> 2     x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
#       3     li=LinearRegression()
#       4     li.fit(x_train, y_train)
#       5     predtrain=li.predict(x_train)
#
# NameError: name 'X_scaled' is not defined

# %%
for i in range(1,500):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    re=RandomForestRegressor()
    re.fit(x_train, y_train)
    predtrain=re.predict(x_train)
    predtest=re.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.7802983156061528
# At random state, 1, the testing accuracy is :0.5655355981867698
#
#
# At random state, 2, the training accuracy is :0.8578289493301451
# At random state, 2, the testing accuracy is :0.4774299616865302
#
#
# At random state, 3, the training accuracy is :0.8114296436995385
# At random state, 3, the testing accuracy is :0.5641128299545135
#
#
# At random state, 4, the training accuracy is :0.8746341713117103
# At random state, 4, the testing accuracy is :0.1812569493287175
#
#
# At random state, 5, the training accuracy is :0.8024148151593071
# At random state, 5, the testing accuracy is :0.6256021718716326
#
#
# At random state, 6, the training accuracy is :0.7394801700053079
# At random state, 6, the testing accuracy is :0.611876349971185
#
#
# At random state, 7, the training accuracy is :0.853483316065422
# At random state, 7, the testing accuracy is :0.20638680961411293
#
#
# ...

# %% [raw]
# At random state, 102, the training accuracy is :0.8758329939993625
# At random state, 102, the testing accuracy is :0.799398488898343

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    de=DecisionTreeRegressor()
    de.fit(x_train, y_train)
    predtrain=de.predict(x_train)
    predtest=de.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :1.0
# At random state, 1, the testing accuracy is :-0.04475259057951053
#
#
# At random state 2, the training accuracy is :1.0
# At random state, 2, the testing accuracy is :0.4817696476535839
#
#
# At random state 3, the training accuracy is :1.0
# At random state, 3, the testing accuracy is :0.3604221078183443
#
#
# At random state 4, the training accuracy is :1.0
# At random state, 4, the testing accuracy is :0.33235665641970447
#
#
# At random state 5, the training accuracy is :1.0
# At random state, 5, the testing accuracy is :0.49400892404211294
#
#
# At random state 6, the training accuracy is :1.0
# At random state, 6, the testing accuracy is :0.5072495726434763
#
#
# At random state 7, the training accuracy is :1.0
# At random state, 7, the testing accuracy is :-1.2475081124622593
#
#
# At random state 8, the training accuracy is :1.0
# At random state, 8, the testing accuracy is :0.08816043602015489
#
#
# ...

# %% [raw]
# At random state 788, the training accuracy is :1.0
# At random state, 788, the testing accuracy is :0.7518645784175243

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    xg=XGBRegressor()
    xg.fit(x_train, y_train)
    predtrain=xg.predict(x_train)
    predtest=xg.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :0.9999997450670229
# At random state, 1, the testing accuracy is :0.2866737277754353
#
#
# At random state 2, the training accuracy is :0.9999995611076622
# At random state, 2, the testing accuracy is :0.5471279339741839
#
#
# At random state 3, the training accuracy is :0.999999445999977
# At random state, 3, the testing accuracy is :0.7204556183080062
#
#
# At random state 4, the training accuracy is :0.9999991224577678
# At random state, 4, the testing accuracy is :0.3174033615975186
#
#
# At random state 5, the training accuracy is :0.9999995131887265
# At random state, 5, the testing accuracy is :0.6743257827765601
#
#
# At random state 6, the training accuracy is :0.9999996983040021
# At random state, 6, the testing accuracy is :0.8491135093862238
#
#
# At random state 7, the training accuracy is :0.9999993883230566
# At random state, 7, the testing accuracy is :-0.19565845681255056
#
#
# ...

# %% [raw]
# At random state 584, the training accuracy is :0.9999998055813134
# At random state, 584, the testing accuracy is :0.8458231062383801

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    ad=AdaBoostRegressor()
    ad.fit(x_train, y_train)
    predtrain=ad.predict(x_train)
    predtest=ad.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.8139086705189053
# At random state, 1, the testing accuracy is :0.25657884077097126
#
#
# At random state, 2, the training accuracy is :0.8125385947541129
# At random state, 2, the testing accuracy is :0.40754537276547276
#
#
# At random state, 3, the training accuracy is :0.7224124671503926
# At random state, 3, the testing accuracy is :0.4608426563774738
#
#
# At random state, 4, the training accuracy is :0.676633429177464
# At random state, 4, the testing accuracy is :0.20471251001758284
#
#
# At random state, 5, the training accuracy is :0.7916415260043229
# At random state, 5, the testing accuracy is :0.3134725946841159
#
#
# At random state, 6, the training accuracy is :0.7888999007740376
# At random state, 6, the testing accuracy is :0.3735655805095097
#
#
# At random state, 7, the training accuracy is :0.8131140189913494
# At random state, 7, the testing accuracy is :-0.17949114626103557
#
#
# ...

# %% [raw]
# At random state, 590, the training accuracy is :0.793074494122773
# At random state, 590, the testing accuracy is :0.7104258136941397

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    kn=KNeighborsRegressor()
    kn.fit(x_train, y_train)
    predtrain=kn.predict(x_train)
    predtest=kn.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :-1.0243632861834158
# At random state, 1, the testing accuracy is :-0.4519922634791833
#
#
# At random state 2, the training accuracy is :-0.7333939355047607
# At random state, 2, the testing accuracy is :0.1823782856538999
#
#
# At random state 3, the training accuracy is :-0.8406375010225171
# At random state, 3, the testing accuracy is :-0.06251600522442136
#
#
# At random state 4, the training accuracy is :-0.5628030308951348
# At random state, 4, the testing accuracy is :0.0621696775834949
#
#
# At random state 5, the training accuracy is :-0.8280811366136578
# At random state, 5, the testing accuracy is :3.1402012345971286e-05
#
#
# At random state 6, the training accuracy is :-0.8831320137713967
# At random state, 6, the testing accuracy is :0.1856831927276812
#
#
# At random state 7, the training accuracy is :-0.9612674060332946
# At random state, 7, the testing accuracy is :-1.1425567187221861
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    gc=GradientBoostingRegressor()
    gc.fit(x_train, y_train)
    predtrain=gc.predict(x_train)
    predtest=gc.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.9851113909448815
# At random state, 1, the testing accuracy is :0.13561616322294956
#
#
# At random state, 2, the training accuracy is :0.9753328668472441
# At random state, 2, the testing accuracy is :0.5849667907964766
#
#
# At random state, 3, the training accuracy is :0.9774208557204899
# At random state, 3, the testing accuracy is :0.504911934216784
#
#
# At random state, 4, the training accuracy is :0.9759226749079913
# At random state, 4, the testing accuracy is :0.21679274952997218
#
#
# At random state, 5, the training accuracy is :0.9733341434277769
# At random state, 5, the testing accuracy is :0.5780499125062677
#
#
# At random state, 6, the training accuracy is :0.9821196698774258
# At random state, 6, the testing accuracy is :0.6103292211997189
#
#
# At random state, 7, the training accuracy is :0.984247051588874
# At random state, 7, the testing accuracy is :0.002265315341096419
#
#
# ...

# %% [raw]
# At random state, 487, the training accuracy is :0.979025623895855
# At random state, 487, the testing accuracy is :0.8260123726397017

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=i)
    sr=SVR()
    sr.fit(x_train, y_train)
    predtrain=sr.predict(x_train)
    predtest=sr.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :-52732079981.06654
# At random state, 1, the testing accuracy is :-0.0752093102363054
#
#
# At random state 2, the training accuracy is :-44366433006.06865
# At random state, 2, the testing accuracy is :-0.07901835975923577
#
#
# At random state 3, the training accuracy is :-48147328657.71272
# At random state, 3, the testing accuracy is :-0.06707252987950985
#
#
# At random state 4, the training accuracy is :-25272745049.199245
# At random state, 4, the testing accuracy is :-0.06175002151025977
#
#
# At random state 5, the training accuracy is :-54717289671.74118
# At random state, 5, the testing accuracy is :-0.05953303358583706
#
#
# At random state 6, the training accuracy is :-53520327128.520134
# At random state, 6, the testing accuracy is :-0.051822375749241534
#
#
# At random state 7, the training accuracy is :-63660260019.06817
# At random state, 7, the testing accuracy is :-0.006501322399625309
#
#
# ...

# %%
# Importing PCA components
from sklearn.decomposition import PCA

# %%
pca=PCA()
pca.fit_transform(X_scaled)
# Out:
# array([[-0.29110824,  1.03568317, -1.52781885, -0.76659471,  0.00920957],
#        [-0.19242646,  0.37516019, -1.00225668,  0.0082363 , -0.03781117],
#        [ 0.42491984,  0.90996997, -1.10977835,  0.28005294,  0.21066176],
#        ...,
#        [-1.36172924,  0.20394174,  0.76852336, -0.32078269,  0.15515295],
#        [-0.52297003, -0.02281077, -1.10019387, -0.70733783,  0.15427049],
#        [-0.47919242, -0.14575762, -0.94929281, -0.41126401,  0.0939314 ]])

# %%
# Ploting Scree plot to check the best components
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Pricipal Components')
plt.ylabel('Variance Covered')
plt.title('PCA')
plt.show()

# %%
pca=PCA(n_components=4)
new_pcomp=pca.fit_transform(X_scaled)
prin_comp=pd.DataFrame(new_pcomp, columns=['PC1','PC2','PC3','PC4'])

# %%
prin_comp
# Out:
#           PC1       PC2       PC3       PC4
# 0   -0.291108  1.035683 -1.527819 -0.766595
# 1   -0.192426  0.375160 -1.002257  0.008236
# 2    0.424920  0.909970 -1.109778  0.280053
# 3   -0.157736 -0.413515 -0.759176 -0.168501
# 4   -1.252017 -0.608669  1.194559 -0.000352
# ..        ...       ...       ...       ...
# 217 -0.429139 -0.272068  1.255841  0.532373
# 218  0.844849  1.083695 -0.992986  0.799550
# 219 -1.361729  0.203942  0.768523 -0.320783
# 220 -0.522970 -0.022811 -1.100194 -0.707338
# 221 -0.479192 -0.145758 -0.949293 -0.411264
#
# [222 rows x 4 columns]

# %%
for i in range(1,2000):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    li=LinearRegression()
    li.fit(x_train, y_train)
    predtrain=li.predict(x_train)
    predtest=li.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :-9.096069158259544
# At random state, 1, the testing accuracy is :-0.0950359198435573
#
#
# At random state, 2, the training accuracy is :-11.131526837951508
# At random state, 2, the testing accuracy is :0.09567055573383365
#
#
# At random state, 3, the training accuracy is :-13.61276640668744
# At random state, 3, the testing accuracy is :0.1390350848087294
#
#
# At random state, 4, the training accuracy is :-3.648851064923864
# At random state, 4, the testing accuracy is :-0.040566138617760705
#
#
# At random state, 5, the training accuracy is :-10.926890439453175
# At random state, 5, the testing accuracy is :0.11532466803264063
#
#
# At random state, 6, the training accuracy is :-11.491678026587781
# At random state, 6, the testing accuracy is :0.12254082767634455
#
#
# At random state, 7, the training accuracy is :-8.458258099074445
# At random state, 7, the testing accuracy is :-0.9399218792491519
#
#
# ...

# %%
for i in range(1,500):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    re=RandomForestRegressor()
    re.fit(x_train, y_train)
    predtrain=re.predict(x_train)
    predtest=re.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.7330386450800921
# At random state, 1, the testing accuracy is :0.30394621802983435
#
#
# At random state, 2, the training accuracy is :0.8244271966343426
# At random state, 2, the testing accuracy is :0.12961890729234804
#
#
# At random state, 3, the training accuracy is :0.8081899447868457
# At random state, 3, the testing accuracy is :0.10741146895812503
#
#
# At random state, 4, the training accuracy is :0.8030243554665175
# At random state, 4, the testing accuracy is :0.018507157777483463
#
#
# At random state, 5, the training accuracy is :0.7451546884464664
# At random state, 5, the testing accuracy is :-0.03845314007312628
#
#
# At random state, 6, the training accuracy is :0.6941390627987188
# At random state, 6, the testing accuracy is :0.36367054210591765
#
#
# At random state, 7, the training accuracy is :0.6629476086502921
# At random state, 7, the testing accuracy is :-0.019630696029808492
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    de=DecisionTreeRegressor()
    de.fit(x_train, y_train)
    predtrain=de.predict(x_train)
    predtest=de.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :1.0
# At random state, 1, the testing accuracy is :-5.6012524297116455
#
#
# At random state 2, the training accuracy is :1.0
# At random state, 2, the testing accuracy is :0.027983403737785295
#
#
# At random state 3, the training accuracy is :1.0
# At random state, 3, the testing accuracy is :-0.18896080862965703
#
#
# At random state 4, the training accuracy is :1.0
# At random state, 4, the testing accuracy is :0.008908905638810194
#
#
# At random state 5, the training accuracy is :1.0
# At random state, 5, the testing accuracy is :-0.6325171464778205
#
#
# At random state 6, the training accuracy is :1.0
# At random state, 6, the testing accuracy is :-0.5188142898548633
#
#
# At random state 7, the training accuracy is :1.0
# At random state, 7, the testing accuracy is :-1.3974214270627918
#
#
# At random state 8, the training accuracy is :1.0
# At random state, 8, the testing accuracy is :0.04856485404406197
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    xg=XGBRegressor()
    xg.fit(x_train, y_train)
    predtrain=xg.predict(x_train)
    predtest=xg.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :0.9999998539565261
# At random state, 1, the testing accuracy is :-1.0620210047423098
#
#
# At random state 2, the training accuracy is :0.9999998718284993
# At random state, 2, the testing accuracy is :0.06048430527207549
#
#
# At random state 3, the training accuracy is :0.9999996155921028
# At random state, 3, the testing accuracy is :0.06256303130379337
#
#
# At random state 4, the training accuracy is :0.9999992056924233
# At random state, 4, the testing accuracy is :0.1442234051985607
#
#
# At random state 5, the training accuracy is :0.9999999600025259
# At random state, 5, the testing accuracy is :0.2503715376333795
#
#
# At random state 6, the training accuracy is :0.9999998241961906
# At random state, 6, the testing accuracy is :0.2771179390926032
#
#
# At random state 7, the training accuracy is :0.9999997626234662
# At random state, 7, the testing accuracy is :-0.00789565346798371
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    ad=AdaBoostRegressor()
    ad.fit(x_train, y_train)
    predtrain=ad.predict(x_train)
    predtest=ad.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.6612539019644426
# At random state, 1, the testing accuracy is :0.29273761887748084
#
#
# At random state, 2, the training accuracy is :0.6929354635008973
# At random state, 2, the testing accuracy is :0.006440884617844755
#
#
# At random state, 3, the training accuracy is :0.675339367304177
# At random state, 3, the testing accuracy is :0.0015074705902179408
#
#
# At random state, 4, the training accuracy is :0.3265292036696429
# At random state, 4, the testing accuracy is :-0.03140806239084193
#
#
# At random state, 5, the training accuracy is :0.6666708021832322
# At random state, 5, the testing accuracy is :0.04889568646997644
#
#
# At random state, 6, the training accuracy is :0.7101832327649444
# At random state, 6, the testing accuracy is :0.03986552751692862
#
#
# At random state, 7, the training accuracy is :0.7216571040631392
# At random state, 7, the testing accuracy is :-1.1282204720763707
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    kn=KNeighborsRegressor()
    kn.fit(x_train, y_train)
    predtrain=kn.predict(x_train)
    predtest=kn.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :-1.0329044695028111
# At random state, 1, the testing accuracy is :-0.4962830155909288
#
#
# At random state 2, the training accuracy is :-0.7893145798434755
# At random state, 2, the testing accuracy is :0.18350084894671437
#
#
# At random state 3, the training accuracy is :-0.858572348082034
# At random state, 3, the testing accuracy is :-0.15937012749082058
#
#
# At random state 4, the training accuracy is :-0.6123484658459994
# At random state, 4, the testing accuracy is :0.06286181075317232
#
#
# At random state 5, the training accuracy is :-0.8335650129079686
# At random state, 5, the testing accuracy is :-0.05278081499454812
#
#
# At random state 6, the training accuracy is :-0.8698560818806258
# At random state, 6, the testing accuracy is :0.14640223700037314
#
#
# At random state 7, the training accuracy is :-1.0410685842384342
# At random state, 7, the testing accuracy is :-1.0743196837810545
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    gc=GradientBoostingRegressor()
    gc.fit(x_train, y_train)
    predtrain=gc.predict(x_train)
    predtest=ad.predict(x_test)
    print(f"At random state, {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state, 1, the training accuracy is :0.9725854189737058
# At random state, 1, the testing accuracy is :0.3849775388589822
#
#
# At random state, 2, the training accuracy is :0.9824343338591878
# At random state, 2, the testing accuracy is :0.37020884893216033
#
#
# At random state, 3, the training accuracy is :0.9756256686497825
# At random state, 3, the testing accuracy is :0.27739128518084644
#
#
# At random state, 4, the training accuracy is :0.9626226660835213
# At random state, 4, the testing accuracy is :0.9188395736921781
#
#
# At random state, 5, the training accuracy is :0.9777446944763735
# At random state, 5, the testing accuracy is :0.02617846117300926
#
#
# At random state, 6, the training accuracy is :0.977187952288621
# At random state, 6, the testing accuracy is :0.13651884784516088
#
#
# At random state, 7, the training accuracy is :0.9743086678204569
# At random state, 7, the testing accuracy is :0.17189018100221598
#
#
# ...

# %%
for i in range(1,800):
    x_train,x_test,y_train, y_test=train_test_split(prin_comp,y,test_size=.20, random_state=i)
    sr=SVR()
    sr.fit(x_train, y_train)
    predtrain=sr.predict(x_train)
    predtest=sr.predict(x_test)
    print(f"At random state {i}, the training accuracy is :{r2_score(predtrain,y_train)}")
    print(f"At random state, {i}, the testing accuracy is :{r2_score(y_test, predtest)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is :-47792351592.41618
# At random state, 1, the testing accuracy is :-0.07520918917189778
#
#
# At random state 2, the training accuracy is :-40886774174.85947
# At random state, 2, the testing accuracy is :-0.07901834695391163
#
#
# At random state 3, the training accuracy is :-43311097260.05277
# At random state, 3, the testing accuracy is :-0.06707219140070575
#
#
# At random state 4, the training accuracy is :-22341059343.66787
# At random state, 4, the testing accuracy is :-0.06175002838738264
#
#
# At random state 5, the training accuracy is :-50006523346.86861
# At random state, 5, the testing accuracy is :-0.05953304973567164
#
#
# At random state 6, the training accuracy is :-47453891173.51417
# At random state, 6, the testing accuracy is :-0.05182245360546012
#
#
# At random state 7, the training accuracy is :-58504347133.08856
# At random state, 7, the testing accuracy is :-0.006500478354326766
#
#
# ...

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=487)
gc=GradientBoostingRegressor()
gc.fit(x_train, y_train)
predtrain=gc.predict(x_train)
predtest=gc.predict(x_test)
print(f"At random state, {487}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {487}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state, 487, the training accuracy is :0.979025623895855
# At random state, 487, the testing accuracy is :0.7850408776734414

# %%
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# The MAE is 464785.05524486105
# The MSE is 464785.05524486105 and RMSE is 681.7514614908141

# %%
#Hyperparameter tuning
from sklearn.model_selection import GridSearchCV
parameters={'n_estimators' : range(5,10),
           'max_depth': range(5,15),
           'min_samples_split': range(2,15),
           'min_samples_leaf':range(2,15),
           'learning_rate':[0.001,0.01,0.1,1,10]}

# %%
c=GridSearchCV(GradientBoostingRegressor(),param_grid=parameters)
c.fit(x_train, y_train)
print('The beast combination of the parameters are ',c.best_params_)
# Out:
# The beast combination of the parameters are  {'learning_rate': 0.1, 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 9}

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=487)
gc=GradientBoostingRegressor(learning_rate=0.1, max_depth=6, min_samples_leaf=3, min_samples_split=5, n_estimators=9)
gc.fit(x_train, y_train)
predtrain=gc.predict(x_train)
predtest=gc.predict(x_test)
print(f"At random state, {487}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {487}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state, 487, the training accuracy is :0.979025623895855
# At random state, 487, the testing accuracy is :0.7994043712066982

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=584)
xg=XGBRegressor()
xg.fit(x_train, y_train)
predtrain=xg.predict(x_train)
predtest=xg.predict(x_test)
print(f"At random state {584}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {584}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state 584, the training accuracy is :0.9999998055813134
# At random state, 584, the testing accuracy is :0.8458231062383801

# %%
#Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
params={'n_estimators': range(2,15),
        'learning_rate': [0.001, 0.01, 0.1, 10, 100],
              'n_jobs': range(2,15)}

# %%
c=GridSearchCV(XGBRegressor(),param_grid=params)
c.fit(x_train, y_train)
print('The beast combination of the parameters are ',c.best_params_)
# Out:
# The beast combination of the parameters are  {'learning_rate': 0.1, 'n_estimators': 10, 'n_jobs': 2}

# %%
x_train,x_test,y_train, y_test=train_test_split(X_scaled,y,test_size=.20, random_state=584)
xg=XGBRegressor(learning_rate=0.01, n_estimators=10, n_jobs=2)
xg.fit(x_train, y_train)
predtrain=xg.predict(x_train)
predtest=xg.predict(x_test)
print(f"At random state {584}, the training accuracy is :{r2_score(predtrain,y_train)}")
print(f"At random state, {584}, the testing accuracy is :{r2_score(y_test, predtest)}")
# Out:
# At random state 584, the training accuracy is :0.9992329390126463
# At random state, 584, the testing accuracy is :0.811913309936757

# %%
# Calculating the MSE, RMSE and MAE for K-NN model
mse=mean_absolute_error(y_test, predtest)
rmse=np.sqrt(mse)
print('The MAE is', mean_absolute_error(y_test, predtest))
print ('The MSE is', mse, 'and RMSE is', rmse)
# Out:
# The MAE is 330812.5414930555
# The MSE is 330812.5414930555 and RMSE is 575.1630564396983

# %%
#pickling
import pickle
filename = 'whp'
outfile = open(filename,'whp')
pickle.dump(sp_dict,outfile)
outfile.close()

# %% [markdown]
# # Conclusion
# It can be seen the model was webscrapped. Then it was made as a dataset which was used for modelling. the data is cleaned and the different graphs were plotted for explorative data analysis. Then the labelencoder is used and catagorical variables were converted to numerical format. Different model were used and XgBoost model was seen to be most efficient. After hyperparameter tuning is at random state 584, the training accuracy is :0.9992329390126463. At random state, 584, the testing accuracy is :0.811913309936757
